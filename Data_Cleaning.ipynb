# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
winedf = pd.read_csv('Data/snooth_api_pull.csv')

# %%
winedf.head(50)
# Out:
#     Unnamed: 0  available                                               code  \
# 0            0          1                      hitching-post-generation-2005
# 1            1          1  villa-farnia-di-farnese-montepulciano-dabruzzo...
# 2            2          1                                   sette-ponti-2007
# 3            3          1               paracombe-shiraz-adelaide-hills-2001
# 4            4          1  vina-misiones-de-rengo-carmenere-rapel-valley-...
# 5            5          1      walnut-crest-merlot-valle-rapel-emiliana-2007
# 6            6          1   castello-monaci-negroamaro-salento-igt-maru-2007
# 7            7          1  finca-sandoval-syrah-blend-manchuela-cuvee-cec...
# 8            8          1  wait-cellars-green-valley-pinot-noir-devoto-ga...
# 9            9          1                      zd-wines-pinot-noir-napa-2008
# 10          10          1  domaine-chante-cigale-chateauneuf-du-pape-bott...
# ...

# %%
winedf = winedf.drop(['tags', 'winery_id', 'available'], axis=1)

# %%
winedf = winedf.drop(['Unnamed: 0'], axis=1)

# %%
winedf.head(20)
# Out:
#                                                  code  \
# 0                       hitching-post-generation-2005
# 1   villa-farnia-di-farnese-montepulciano-dabruzzo...
# 2                                    sette-ponti-2007
# 3                paracombe-shiraz-adelaide-hills-2001
# 4   vina-misiones-de-rengo-carmenere-rapel-valley-...
# 5       walnut-crest-merlot-valle-rapel-emiliana-2007
# 6    castello-monaci-negroamaro-salento-igt-maru-2007
# 7   finca-sandoval-syrah-blend-manchuela-cuvee-cec...
# 8   wait-cellars-green-valley-pinot-noir-devoto-ga...
# 9                       zd-wines-pinot-noir-napa-2008
# 10  domaine-chante-cigale-chateauneuf-du-pape-bott...
# 11  standing-stone-vineyards-pinot-noir-finger-lak...
# 12               swanson-vineyards-alexis-estate-2010
# 13               swanson-vineyards-alexis-estate-2009
# 14                         alderbrook-pinot-noir-2010
# 15                           las-lajas-torrontes-2010
# ...

# %%
regiondf = winedf.region.str.split(" > ",expand=True)

# %%
print(regiondf.columns)
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
regiondf.head(5)
# Out:
#            0               1                        2                    3  \
# 0        USA      California            Santa Barbara                 None
# 1      Italy         Abruzzi  Montepulciano d'Abruzzo                 None
# 2      Italy         Tuscany                  Maremma  Maremma Toscana Igt
# 3  Australia  Adelaide Hills                     None                 None
# 4      Chile  Central Valley             Rapel Valley                Rengo
#
#       4     5
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None

# %%
winedf['country'] = regiondf[0]

# %%
winedf['region1'] = regiondf[1]

# %%
winedf.head(5)
# Out:
#                                                 code  \
# 0                      hitching-post-generation-2005
# 1  villa-farnia-di-farnese-montepulciano-dabruzzo...
# 2                                   sette-ponti-2007
# 3               paracombe-shiraz-adelaide-hills-2001
# 4  vina-misiones-de-rengo-carmenere-rapel-valley-...
#
#                                                image  \
# 0  http://ei.isnooth.com/multimedia/a/e/1/image_3...
# 1  http://ei.isnooth.com/multimedia/d/5/c/image_7...
# 2  http://ei.isnooth.com/multimedia/5/9/a/image_9...
# 3  http://ei.isnooth.com/multimedia/8/2/e/image_2...
# 4  http://ei.isnooth.com/multimedia/7/d/8/image_1...
#
#                                                 link  \
# 0  http://www.snooth.com/wine/hitching-post-gener...
# 1  http://www.snooth.com/wine/villa-farnia-di-far...
# 2       http://www.snooth.com/wine/sette-ponti-2007/
# 3  http://www.snooth.com/wine/paracombe-shiraz-ad...
# ...

# %%
winedf.drop(['region'], axis = 1)
# Out:
#                                                    code  \
# 0                         hitching-post-generation-2005
# 1     villa-farnia-di-farnese-montepulciano-dabruzzo...
# 2                                      sette-ponti-2007
# 3                  paracombe-shiraz-adelaide-hills-2001
# 4     vina-misiones-de-rengo-carmenere-rapel-valley-...
# 5         walnut-crest-merlot-valle-rapel-emiliana-2007
# 6      castello-monaci-negroamaro-salento-igt-maru-2007
# 7     finca-sandoval-syrah-blend-manchuela-cuvee-cec...
# 8     wait-cellars-green-valley-pinot-noir-devoto-ga...
# 9                         zd-wines-pinot-noir-napa-2008
# 10    domaine-chante-cigale-chateauneuf-du-pape-bott...
# 11    standing-stone-vineyards-pinot-noir-finger-lak...
# 12                 swanson-vineyards-alexis-estate-2010
# 13                 swanson-vineyards-alexis-estate-2009
# 14                           alderbrook-pinot-noir-2010
# 15                             las-lajas-torrontes-2010
# ...

# %%
winedf = winedf.drop(['code', 'num_merchants'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-ff5a6703284a> in <module>
# ----> 1 winedf = winedf.drop(['code', 'num_merchants'], axis = 1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
winedf = winedf.drop(['region'], axis = 1)

# %%
winedf = winedf.rename(columns={"region1": "region"})
winedf.head()
# Out:
#                                                image  \
# 0  http://ei.isnooth.com/multimedia/a/e/1/image_3...
# 1  http://ei.isnooth.com/multimedia/d/5/c/image_7...
# 2  http://ei.isnooth.com/multimedia/5/9/a/image_9...
# 3  http://ei.isnooth.com/multimedia/8/2/e/image_2...
# 4  http://ei.isnooth.com/multimedia/7/d/8/image_1...
#
#                                                 link  \
# 0  http://www.snooth.com/wine/hitching-post-gener...
# 1  http://www.snooth.com/wine/villa-farnia-di-far...
# 2       http://www.snooth.com/wine/sette-ponti-2007/
# 3  http://www.snooth.com/wine/paracombe-shiraz-ad...
# 4  http://www.snooth.com/wine/vina-misiones-de-re...
#
#                                                 name  num_reviews   price  \
# 0                           Hitching Post Generation            1   15.99
# 1    Villa Farnia di Farnese Montepulciano d'Abruzzo            5   20.75
# 2                                        Sette Ponti            6  104.99
# ...

# %%
winedf.head(20)
# Out:
#                                                 image  \
# 0   http://ei.isnooth.com/multimedia/a/e/1/image_3...
# 1   http://ei.isnooth.com/multimedia/d/5/c/image_7...
# 2   http://ei.isnooth.com/multimedia/5/9/a/image_9...
# 3   http://ei.isnooth.com/multimedia/8/2/e/image_2...
# 4   http://ei.isnooth.com/multimedia/7/d/8/image_1...
# 5   http://ei.isnooth.com/multimedia/e/e/d/image_6...
# 6   http://ei.isnooth.com/multimedia/1/6/9/image_8...
# 7   http://ei.isnooth.com/multimedia/9/e/a/image_1...
# 8   http://ei.isnooth.com/multimedia/f/d/5/image_3...
# 9   http://ei.isnooth.com/multimedia/d/7/4/image_1...
# 10  http://ei.isnooth.com/multimedia/6/0/8/image_9...
# 11  http://ei.isnooth.com/multimedia/d/6/d/image_7...
# 12  http://ei.isnooth.com/multimedia/9/4/2/image_3...
# 13  http://ei.isnooth.com/multimedia/9/d/f/image_2...
# 14  http://ei.isnooth.com/multimedia/7/1/d/image_2...
# 15  http://ei.isnooth.com/multimedia/f/3/6/image_2...
# ...

# %%
winedf['varietal'].isna()
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12       True
# 13       True
# 14      False
# 15      False
# 16       True
# 17      False
# 18      False
# 19       True
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 9970    False
# 9971    False
# 9972    False
# 9973    False
# 9974     True
# 9975    False
# 9976    False
# 9977    False
# 9978    False
# 9979    False
# 9980    False
# 9981    False
# 9982    False
# 9983    False
# 9984    False
# 9985    False
# 9986    False
# 9987    False
# 9988    False
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# 9994    False
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# ...

# %%
winedf = winedf[pd.notnull(winedf['varietal'])]

# %%
winedf = winedf[pd.notnull(winedf['country'])]

# %%
winedf = winedf[pd.notnull(winedf['region'])]

# %%
winedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8635 entries, 0 to 9998
# Data columns (total 12 columns):
# image          8635 non-null object
# link           8635 non-null object
# name           8635 non-null object
# num_reviews    8635 non-null int64
# price          8635 non-null float64
# snoothrank     5071 non-null float64
# type           7711 non-null object
# varietal       8635 non-null object
# vintage        8613 non-null object
# winery         8633 non-null object
# country        8635 non-null object
# region         8635 non-null object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 877.0+ KB

# %%
winedf.head()
# Out:
#                                                image  \
# 0  http://ei.isnooth.com/multimedia/a/e/1/image_3...
# 1  http://ei.isnooth.com/multimedia/d/5/c/image_7...
# 3  http://ei.isnooth.com/multimedia/8/2/e/image_2...
# 4  http://ei.isnooth.com/multimedia/7/d/8/image_1...
# 5  http://ei.isnooth.com/multimedia/e/e/d/image_6...
#
#                                                 link  \
# 0  http://www.snooth.com/wine/hitching-post-gener...
# 1  http://www.snooth.com/wine/villa-farnia-di-far...
# 3  http://www.snooth.com/wine/paracombe-shiraz-ad...
# 4  http://www.snooth.com/wine/vina-misiones-de-re...
# 5  http://www.snooth.com/wine/walnut-crest-merlot...
#
#                                                 name  num_reviews  price  \
# 0                           Hitching Post Generation            1  15.99
# 1    Villa Farnia di Farnese Montepulciano d'Abruzzo            5  20.75
# 3                    Paracombe Shiraz Adelaide Hills           12  69.99
# ...

# %%
len(winedf.varietal.unique())
# Out:
# 162

# %%
len(winedf.image.unique())
# Out:
# 894
